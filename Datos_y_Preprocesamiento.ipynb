# %% [markdown]
# <a href="https://colab.research.google.com/github/camayli/Trabajo-Final-Aprendiza-Autom-tico-II-/blob/main/Datos_y_Preprocesamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
# TRABAJO FINAL DE APRENDIZAJE AUTOMATICO II
# ```

# %% [markdown]
# # **CARGA DE DATASET & PREPROCESAMIENTO DE DATOS**

# %% [markdown]
# > 1. Carga de DATASET - WATER POTABILITY

# %%
#Instalar dependencias (solo una vez por sesión)
# !pip install -q kagglehub[pandas-datasets]

# %%
#Imports
import kagglehub
from kagglehub import KaggleDatasetAdapter

# %%
#Path del archivo dentro del dataset
# En este dataset el archivo se llama:
file_path = "water_potability.csv"

# %%
#Cargar el dataset en un DataFrame de pandas
df = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    "adityakadiwal/water-potability",
    file_path,
)
# Out:
# /tmp/ipython-input-1094881359.py:2: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# Using Colab cache for faster access to the 'water-potability' dataset.

# %%
#Verificar carga
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.info()

# %%
df['Potability'].value_counts()

# %%
df.isna().sum()

# %%
df.shape

# %%
import matplotlib.pyplot as plt

df.hist(bins=30, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
X = df.drop(columns='Potability')
y = df['Potability']

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=2)

X_imputed = imputer.fit_transform(X)
X_imputed = pd.DataFrame(X_imputed, columns=X.columns)

# %%
X_imputed
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     6.007427  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  326.479827
# 2     8.099124  224.236259  19909.541732     9.275884  357.947334
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  355.544770
# 3273  9.419510  175.762646  33155.578218     7.350233  321.930158
# 3274  5.126763  230.603758  11983.869376     6.303357  338.733772
# 3275  7.874671  195.102299  17404.177061     7.509306  335.431261
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# ...

# %%
X_imputed.isna().sum()
